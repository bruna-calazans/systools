# %% [markdown]
# # Practic examples of Systools Data Module

# %% [markdown]
# ### Importing the main module...

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from systools import data
import pandas as pd

# %% [markdown]
# ### <span style="color:blue">**open_file**</span>

# %% [markdown]
# Open various types of file, using only this function!
#
#                                                          Files Suported:
#
# | .csv | .txt | .parquet | .xlsx | .shape | .dbf |
# |------|------|----------|-------|--------|------|

# %% [markdown]
# In this example, we will be opening various types of file, 4 text type files and 2 geographic type files:
#
# - The text types are related to a BHTrans (Agency of Transportation of Belo Horizonte) traffic acidents report.
# - The geographic type files are related to the estate of Minas Gerais Municipalities.

# %% [markdown]
# <span style="color:red">**The error that appear in the next row is very usual, caused by the different encodings each file has, continue reading to see how to bypass this...**</span>

# %%
txt = data.open_file(r'examples_databases\open_file\si-log-2020.txt')
txt.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 txt = data.open_file(r'examples_databases\open_file\si-log-2020.txt')
#       2 txt.head()
#
# File ~\PycharmProjects\systools_for_pip\systools\data.py:131, in open_file(path, name, expected_cols, usa, col_td_prefix, col_dt_prefix, **kwargs)
#      93 def open_file(path, name=None, expected_cols=None, usa=False, col_td_prefix='gap',  col_dt_prefix='H_', **kwargs):
#      95     """
#      96     Open file as a DataFrame.
#      97     Support csv, txt, parquet, excel and shape.
#    (...)
#     128
#     129     """
# --> 131     df = rW.load_file(path, name, expected_cols, usa, **kwargs)
#     133     # Configure Formats
#     134     df = dataframe2numeric(df, col_dt_prefix, col_td_prefix)
#
# File ~\PycharmProjects\systools_for_pip\systools\helpers\readWrite.py:112, in load_file(path, name, expected_cols, usa, **kwargs)
#     110     df = pd.read_parquet(path + '\\' + name, columns=expected_cols)
#     111 else:
# --> 112     df = load_text_file(path, name, expected_cols, usa, **kwargs)
#     114 return df
#
# File ~\PycharmProjects\systools_for_pip\systools\helpers\readWrite.py:56, in load_text_file(path, name, cols, usa, kwargs)
#      54             df = read(myFile)
#      55 else:
# ---> 56     df = read(os.path.normpath(os.path.join(path, name)))
#      58 # Drop rows that contains only NaN
#      59 df.dropna(how="all", inplace=True)
#
# File ~\PycharmProjects\systools_for_pip\systools\helpers\readWrite.py:47, in load_text_file.<locals>.read(pathname)
#      45     df_ltf = pd.read_excel(pathname, usecols=cols, **kwargs)
#      46 else:
# ---> 47     df_ltf = pd.read_csv(pathname, usecols=cols, **kwargs)
#      48 return df_ltf
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\io\parsers\readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\_libs\parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\_libs\parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\Anaconda3\envs\systra\lib\site-packages\pandas\_libs\parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xba in position 1: invalid start byte

# %% [markdown]
# You just have to add the **encoding kwarg** and the **encoding** type you want. In Brazil, most of the encodings used to preserve information is **latin1**, but in other cases, **utm-8-sig** can be very useful too!

# %%
txt = data.open_file(r'examples_databases\open_file\si-log-2020.txt', kwargs = {'encoding' : 'latin1'})
txt.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
csv = data.open_file(r'examples_databases\open_file\si-log-2020.csv', kwargs = {'encoding' : 'latin1'})
csv.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
parquet = data.open_file(r'examples_databases\open_file\si-log-2020.parquet', kwargs = {'encoding' : 'latin1'})
parquet.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
excel = data.open_file(r'examples_databases\open_file\si-log-2020.xlsx')
excel.head()
# Out:
#    Unnamed: 0          Nº_boletim      data_boletim   Nº_municipio  \
# 0           0  2020-060939318-001  19/12/2020 15:10              1
# 1           1  2020-005366112-001  31/01/2020 15:27              1
# 2           2  2020-040388513-001  21/08/2020 13:14              1
# 3           3  2020-029371860-001  19/06/2020 12:04              1
# 4           4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %% [markdown]
# Like observed, all the opened files are identical, only the **open_file** function was used and in some cases, some **ecoding kwargs**...
# The **open_file** function when used on files that are expected to return text converted to dataframes can be used to every suported file!

# %%
shp = data.open_file(r'examples_databases\open_file\Limites_municipais_MG_linha.shp')
shp.head()
# Out:
#    Id  wdfgsdfg                                           geometry
# 0   0       NaN  LINESTRING (-45.95485 -22.84948, -45.95767 -22...
# 1   0       NaN  LINESTRING (-46.19200 -22.86405, -46.18867 -22...
# 2   0       NaN  LINESTRING (-46.19200 -22.86405, -46.19386 -22...
# 3   0       NaN  LINESTRING (-46.33084 -22.76196, -46.32757 -22...
# 4   0       NaN  LINESTRING (-45.80547 -22.73705, -45.80282 -22...

# %%
dbf = data.open_file(r'examples_databases\open_file\Limites_municipais_MG_linha.dbf')
dbf.head()
# Out:
#    Id  wdfgsdfg                                           geometry
# 0   0       NaN  LINESTRING (-45.95485 -22.84948, -45.95767 -22...
# 1   0       NaN  LINESTRING (-46.19200 -22.86405, -46.18867 -22...
# 2   0       NaN  LINESTRING (-46.19200 -22.86405, -46.19386 -22...
# 3   0       NaN  LINESTRING (-46.33084 -22.76196, -46.32757 -22...
# 4   0       NaN  LINESTRING (-45.80547 -22.73705, -45.80282 -22...

# %% [markdown]
# Like the text files that were readed as **DataFrames**, the geographic files readed returned equal **DataFrames**, but the geographic version of it, used in **GeoPandas** and with the geometry column for each value, just having to use the **open_file** function!
#
# <span style="color:red">**Obs: The open_file function can be used without any extra parameter and kwargs, like showed above, but for a plenty use, is recomended to read the documentation and understand the possible variations...**</span>

# %% [markdown]
# ### <span style="color:blue">**dataframe2numeric**</span>

# %% [markdown]
# Convert every numeric and time-type columns into a numeric column, datetime column or timedelta column, based ou prefixes. As example we will be using the already uploaded .csv file from last example...

# %%
df = csv.copy()
df.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
df.dtypes
# Out:
# Nº_boletim                  object
# data_boletim                object
#  Nº_municipio                int64
# nome_municipio              object
# seq_logradouros              int64
# Nº_logradouro                int64
# tipo_logradouro             object
# nome_logradouro             object
# tipo_logradouro_anterior    object
# nome_logradouro_anterior    object
# Nº_bairro                    int64
# nome_bairro                 object
# tipo_bairro                 object
# descricao_tipo_bairro       object
# Nº_imovel                   object
# Nº_imovel_proximo            int64
# dtype: object

# %% [markdown]
# Like seemed above, the **DataFrame** contains a datetime column (**data_boletim**) and, and the numeric columns are already converted to numeric types (because the **open_file** function uses the dataframe2numeric function in the backwards) but to convert the time values, we need to pass a parameter like showed before, let's do this then!

# %%
df = df.rename(columns = {'data_boletim' : 'DT_data_boletim'})
df = data.dataframe2numeric(df, col_dt_preffix = 'DT_')

# %%
df.dtypes
# Out:
# Nº_boletim                          object
# DT_data_boletim             datetime64[ns]
#  Nº_municipio                        int64
# nome_municipio                      object
# seq_logradouros                      int64
# Nº_logradouro                        int64
# tipo_logradouro                     object
# nome_logradouro                     object
# tipo_logradouro_anterior            object
# nome_logradouro_anterior            object
# Nº_bairro                            int64
# nome_bairro                         object
# tipo_bairro                         object
# descricao_tipo_bairro               object
# Nº_imovel                           object
# Nº_imovel_proximo                    int64
# dtype: object

# %% [markdown]
# And like promised, the column is now a datetime column!

# %% [markdown]
# ### <span style="color:blue">**save_file**</span>

# %% [markdown]
# Single function used to export a file, the defined extension is defined by the user using parameters, so with only one function you can export various types of files.
#
#                                                          Files Suported:
#
# | .csv | .parquet | .xlsx | .shp |
# |------|----------|-------|------|

# %%
data.save_file(csv, 'examples_databases\save_file', name='csv_file', ext='csv')

# %%
data.save_file(parquet, 'examples_databases\save_file', name='parquet_file', ext='parquet')

# %%
data.save_file(shp, 'examples_databases\save_file', name='shp_file', ext='shp')
# Out:
# C:\Users\pcardoso\Anaconda3\envs\systra\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
data.save_file(excel, 'examples_databases\save_file', name='excel_file', ext='xlsx', sheet_name='Sheet1')

# %% [markdown]
# Done! All DataFrames were saved using only the **save_file** function! Like showed bellow...

# %%
os.listdir('examples_databases\save_file')
# Out:
# ['csv_file.csv',
#  'excel_file.xlsx',
#  'parquet_file.parquet',
#  'shp_file.col',
#  'shp_file.cpg',
#  'shp_file.dbf',
#  'shp_file.prj',
#  'shp_file.shp',
#  'shp_file.shx']

# %% [markdown]
# ### <span style="color:blue">**get_col**</span>

# %% [markdown]
# Function used to do an **"easy merge"** between multiple DataFrames...

# %%
df1 = csv.copy()
df1.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
df2 = data.open_file('examples_databases\get_col\si-bol-2020.csv', kwargs={'encoding' : 'latin1'})
df2.head()
# Out:
#        NUMERO_BOLETIM  DATA HORA_BOLETIM     DATA_INCLUSAO  TIPO_ACIDENTE  \
# 0  2020-011831835-001   07/03/2020 06:00  07/03/2020 06:58         H09002
# 1  2020-011838326-001   07/03/2020 08:27  07/03/2020 08:34         H08002
# 2  2020-011841962-001   07/03/2020 06:53  07/03/2020 09:19         H08002
# 3  2020-011849103-001   07/03/2020 10:10  07/03/2020 10:40         H06002
# 4  2020-011854660-001   07/03/2020 10:48  07/03/2020 11:38         H01002
#
#                                   DESC_TIPO_ACIDENTE   COD_TEMPO  \
# 0  COLISAO DE VEICULOS COM VITIMA                ...           2
# 1  CHOQUE MECANICO COM VITIMA                    ...           2
# 2  CHOQUE MECANICO COM VITIMA                    ...           2
# 3  ATROPELAMENTO DE PESSOA SEM VITIMA FATAL      ...           0
# 4  ABALROAMENTO COM VITIMA                       ...           1
#
#         DESC_TEMPO   COD_PAVIMENTO        PAVIMENTO   COD_REGIONAL  ...  \
# 0  CHUVA                         1  ASFALTO                     25  ...
# 1  CHUVA                         1  ASFALTO                     23  ...
# 2  CHUVA                         1  ASFALTO                      0  ...
# 3  NAO INFORMADO                 0  NAO INFORMADO               25  ...
# 4  BOM                           1  ASFALTO                     18  ...
#
#    VELOCIDADE_PERMITIDA  COORDENADA_X  COORDENADA_Y   HORA_INFORMADA  \
# 0                     0     605836.61    7798624.66              SIM
# 1                    60     610478.49    7810433.11              SIM
# 2                     0     605990.46    7806661.44              SIM
# 3                     0          0.00          0.00              SIM
# 4                     0     600896.61    7789929.77              SIM
#
#     INDICADOR_FATALIDADE   VALOR_UPS  DESCRIÇÃO_UPS  DATA_ALTERACAO_SMSA  \
# 0                    NÃO           0  NÃO INFORMADO           00/00/0000
# 1                    NÃO           0  NÃO INFORMADO           00/00/0000
# 2                    NÃO           0  NÃO INFORMADO           00/00/0000
# 3                    NÃO           0  NÃO INFORMADO           00/00/0000
# 4                    NÃO           0  NÃO INFORMADO           00/00/0000
#
#     VALOR_UPS_ANTIGA  DESCRIÇÃO_UPS_ANTIGA
# 0                  0         NÃO INFORMADO
# 1                  0         NÃO INFORMADO
# 2                  0         NÃO INFORMADO
# 3                  0         NÃO INFORMADO
# 4                  0         NÃO INFORMADO
#
# [5 rows x 23 columns]

# %% [markdown]
# In this example, we will use the **NUMERO_BOLETIM** from df2 and, **N°_boletim** from df1, to perform a merge using the **get_col** function and, get the **' DESC_TIPO_ACIDENTE'** column! If the column name is equal just the key parameter is enough...

# %%
df_get_col = data.get_col(df1, ' DESC_TIPO_ACIDENTE', df2, key=['Nº_boletim'], key2=[' NUMERO_BOLETIM'])
df_get_col.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo  \
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0
#
#                                   DESC_TIPO_ACIDENTE
# 0  ABALROAMENTO COM VITIMA                       ...
# 1  CHOQUE MECANICO COM VITIMA                    ...
# 2  CHOQUE MECANICO COM VITIMA                    ...
# 3  ABALROAMENTO COM VITIMA                       ...
# 4  ABALROAMENTO COM VITIMA                       ...

# %%
' DESC_TIPO_ACIDENTE' in df_get_col.columns
# Out:
# True

# %% [markdown]
# ### <span style="color:blue">**remove_duplicate_safe**</span>

# %% [markdown]
# Remove the duplicates of a DataFrame and show the user the dimension erased duplicates...

# %% [markdown]
# In this example, we will remove all the duplicates inside the column **' nome_bairro'** from the DataFrame, it will result in a large and suspicious number of erased duplicates, so the result will be showed for user...

# %%
df = df_get_col.copy()
df.shape[0]
# Out:
# 14181

# %%
df = data.remove_duplicate_safe(df, cols = 'nome_bairro')
# Out:
# Duplicates removed from [nome_bairro]13,7980.97

# %%
df.shape[0]
# Out:
# 383

# %% [markdown]
# ### <span style="color:blue">**flatten_hierarchical_col**</span>

# %% [markdown]
# Turn **multi-index** column names of a DataFrame, into **single-index** comumn names...

# %% [markdown]
# To exemplify this function, we will create a **multi-index** column names using one already opened **.csv** file!

# %%
df = csv.copy()
df.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
# Creating the multi-index column names ...

df_pivot = df.pivot_table(index='tipo_logradouro', columns=['nome_municipio', 'descricao_tipo_bairro'], values='Nº_boletim', aggfunc='count')

# %%
df_pivot.head()
# Out:
# nome_municipio        BELO HORIZONTE                  \
# descricao_tipo_bairro AREA
# tipo_logradouro
# ACS                                              NaN
# ALA                                              NaN
# AVE                                             21.0
# BEC                                              NaN
# EST                                              NaN
#
# nome_municipio                                        \
# descricao_tipo_bairro BAIRRO
# tipo_logradouro
# ACS                                              NaN
# ALA                                             34.0
# AVE                                           4817.0
# BEC                                             23.0
# EST                                              8.0
#
# nome_municipio                                        \
# descricao_tipo_bairro CONJUNTO HABITACIONAL
# tipo_logradouro
# ACS                                              NaN
# ALA                                              NaN
# AVE                                             70.0
# BEC                                              1.0
# EST                                              NaN
#
# nome_municipio                                        \
# descricao_tipo_bairro GRANJA
# tipo_logradouro
# ACS                                              NaN
# ALA                                              NaN
# AVE                                              NaN
# BEC                                              NaN
# EST                                              NaN
#
# nome_municipio                                        \
# descricao_tipo_bairro JARDIM
# tipo_logradouro
# ACS                                              NaN
# ALA                                              NaN
# AVE                                              NaN
# BEC                                              NaN
# EST                                              NaN
#
# nome_municipio                                        \
# descricao_tipo_bairro PARQUE
# tipo_logradouro
# ACS                                              NaN
# ALA                                              NaN
# AVE                                              5.0
# BEC                                              NaN
# EST                                              NaN
#
# nome_municipio
# descricao_tipo_bairro VILA
# tipo_logradouro
# ACS                                              1.0
# ALA                                              3.0
# AVE                                            270.0
# BEC                                              5.0
# EST                                              NaN

# %%
df_pivot.columns
# Out:
# MultiIndex([('BELO HORIZONTE                ', ...),
#             ('BELO HORIZONTE                ', ...),
#             ('BELO HORIZONTE                ', ...),
#             ('BELO HORIZONTE                ', ...),
#             ('BELO HORIZONTE                ', ...),
#             ('BELO HORIZONTE                ', ...),
#             ('BELO HORIZONTE                ', ...)],
#            names=['nome_municipio', 'descricao_tipo_bairro'])

# %%
# Using function to transform the DataFrame column names

df_pivot.columns = df_pivot.columns.map(data.flatten_hierarchical_col)

# %%
df.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
df_pivot.columns
# Out:
# Index(['BELO HORIZONTE                _AREA                          ',
#        'BELO HORIZONTE                _BAIRRO                        ',
#        'BELO HORIZONTE                _CONJUNTO HABITACIONAL         ',
#        'BELO HORIZONTE                _GRANJA                        ',
#        'BELO HORIZONTE                _JARDIM                        ',
#        'BELO HORIZONTE                _PARQUE                        ',
#        'BELO HORIZONTE                _VILA                          '],
#       dtype='object')

# %% [markdown]
# ### <span style="color:blue">**get_mask_isin**</span>

# %% [markdown]
# Get a **filter mask** to be used in a DataFrame based on single ou multiple filter.

# %%
df = csv.copy()
df.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %% [markdown]
# To exemplify this function, we will create a double filter, based on two reference keys, the column **tipo_bairro** using B and A as filter and the column **tipo_logradouro** using RUA and AVE as filter.

# %% [markdown]
# **Simple Example:**

# %%
mask = data.get_mask_isin(df, 'seq_logradouros', [(1)])
df = df[mask]

# %%
df.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
# 6  2020-028611830-002  15/06/2020 13:24              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
# 6  BELO HORIZONTE                                1         116587
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
# 6             RUA  CEUTA                                         ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
# 6                      RUA  TRES                                          ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
# 6        634  CANAA                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0
# 6  BAIRRO                                 0                  0

# %%
df['seq_logradouros'].value_counts()
# Out:
# 1    10621
# Name: seq_logradouros, dtype: int64

# %% [markdown]
# **Complex Example:**

# %%
df = csv.copy()
mask = data.get_mask_isin(df, [' Nº_municipio', 'seq_logradouros'], [(1, 1), (1, 2)])
df = df[mask]

# %%
df.head()
# Out:
#            Nº_boletim      data_boletim   Nº_municipio  \
# 0  2020-060939318-001  19/12/2020 15:10              1
# 1  2020-005366112-001  31/01/2020 15:27              1
# 2  2020-040388513-001  21/08/2020 13:14              1
# 3  2020-029371860-001  19/06/2020 12:04              1
# 4  2020-054108200-001  09/11/2020 14:08              1
#
#                    nome_municipio  seq_logradouros  Nº_logradouro  \
# 0  BELO HORIZONTE                                1         117712
# 1  BELO HORIZONTE                                1         117712
# 2  BELO HORIZONTE                                2         117712
# 3  BELO HORIZONTE                                1         117712
# 4  BELO HORIZONTE                                1         117712
#
#   tipo_logradouro                                    nome_logradouro  \
# 0             RUA  JOAO ARANTES                                  ...
# 1             RUA  JOAO ARANTES                                  ...
# 2             RUA  JOAO ARANTES                                  ...
# 3             RUA  JOAO ARANTES                                  ...
# 4             RUA  JOAO ARANTES                                  ...
#
#   tipo_logradouro_anterior                           nome_logradouro_anterior  \
# 0                      RUA  CINQUENTA E UM                                ...
# 1                      RUA  CINQUENTA E UM                                ...
# 2                      RUA  CINQUENTA E UM                                ...
# 3                      RUA  CINQUENTA E UM                                ...
# 4                      RUA  CINQUENTA E UM                                ...
#
#    Nº_bairro                                        nome_bairro tipo_bairro  \
# 0        808  UNIAO                                         ...          B
# 1        808  UNIAO                                         ...          B
# 2        645  CIDADE NOVA                                   ...          B
# 3        645  CIDADE NOVA                                   ...          B
# 4        808  UNIAO                                         ...          B
#
#             descricao_tipo_bairro Nº_imovel  Nº_imovel_proximo
# 0  BAIRRO                                 0                  0
# 1  BAIRRO                               341                  0
# 2  BAIRRO                                 0                  0
# 3  BAIRRO                                 0                  0
# 4  BAIRRO                                25                  0

# %%
df[' Nº_municipio'].value_counts()
# Out:
# 1    14178
# Name:  Nº_municipio, dtype: int64

# %%
df['seq_logradouros'].value_counts()
# Out:
# 1    10621
# 2     3557
# Name: seq_logradouros, dtype: int64

# %% [markdown]
# Like showed above, the single-filter and multi-filter from the **get_mask_isin** function, worked!
